# %% [markdown]
# # Quick and dirty maps with matplotlib and cartopy

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# We will use cartopy to draw maps
import cartopy
import cartopy.crs as ccrs

# %matplotlib inline

# %%
map_proj = ccrs.PlateCarree(central_longitude=0.0, globe=None)

fig = plt.figure(figsize=(15, 15))
ax = plt.axes(projection=map_proj)


ax.add_feature(cartopy.feature.LAND)
ax.add_feature(cartopy.feature.OCEAN)
ax.add_feature(cartopy.feature.COASTLINE, edgecolor='#D3B962')
ax.add_feature(cartopy.feature.BORDERS, linestyle=':', edgecolor='#D3B962')
# Out:
# D:\Anaconda3\envs\d_py36_vis-tutorial\lib\site-packages\cartopy\io\__init__.py:260: DownloadWarning: Downloading: https://naciscdn.org/naturalearth/110m/physical/ne_110m_land.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)
# D:\Anaconda3\envs\d_py36_vis-tutorial\lib\site-packages\cartopy\io\__init__.py:260: DownloadWarning: Downloading: https://naciscdn.org/naturalearth/110m/physical/ne_110m_ocean.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)
# D:\Anaconda3\envs\d_py36_vis-tutorial\lib\site-packages\cartopy\io\__init__.py:260: DownloadWarning: Downloading: https://naciscdn.org/naturalearth/110m/physical/ne_110m_coastline.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)
# D:\Anaconda3\envs\d_py36_vis-tutorial\lib\site-packages\cartopy\io\__init__.py:260: DownloadWarning: Downloading: https://naciscdn.org/naturalearth/110m/cultural/ne_110m_admin_0_boundary_lines_land.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)

# %%
df_plants_eu = pd.read_csv('./data/conventional_power_plants_EU.csv', index_col=0)
df_plants_de = pd.read_csv('./data/conventional_power_plants_DE.csv', index_col=0)

df_plants_eu = df_plants_eu.dropna(subset=['lat', 'lon'], how='any')
df_plants_de = df_plants_de.dropna(subset=['lat', 'lon'], how='any')

# %%
df_plants_eu.head(2)
# Out:
#      company            street postcode    city country  capacity  \
# name
# AL-1    NUON  Marketkant 12-10   1341AK  Almere      NL      62.0
# AL-2    NUON  Markerkant 12-10   1341AK  Almere      NL      55.0
#
#      energy_source technology additional_info type  chp  commissioned comment  \
# name
# AL-1   Natural gas        NaN             NaN  NaN  NaN           NaN     NaN
# AL-2   Natural gas        NaN             NaN  NaN  NaN           NaN     NaN
#
#          source eic_code       lat     lon energy_source_level_1  \
# name
# AL-1  Tennet_Q1      NaN  52.38811  5.2154          Fossil fuels
# AL-2  Tennet_Q4      NaN  52.38811  5.2154          Fossil fuels
#
#      energy_source_level_2 energy_source_level_3
# name
# AL-1           Natural gas                   NaN
# AL-2           Natural gas                   NaN

# %%
map_proj = ccrs.PlateCarree(central_longitude=0.0, globe=None)

fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection=map_proj)

ax.add_feature(cartopy.feature.LAND)
ax.add_feature(cartopy.feature.OCEAN)

# Plot all EU plants in blue
plt.plot(
    df_plants_eu.lon, df_plants_eu.lat,
    color='blue', lw=0, marker='o',
    transform=map_proj
)

# Plot all German plants in red
plt.plot(
    df_plants_de.lon, df_plants_de.lat,
    color='red', lw=0, marker='o',
    transform=map_proj
)
# Out:
# D:\Anaconda3\envs\d_py36_vis-tutorial\lib\site-packages\cartopy\io\__init__.py:260: DownloadWarning: Downloading: https://naciscdn.org/naturalearth/50m/physical/ne_50m_land.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)
# D:\Anaconda3\envs\d_py36_vis-tutorial\lib\site-packages\cartopy\io\__init__.py:260: DownloadWarning: Downloading: https://naciscdn.org/naturalearth/50m/physical/ne_50m_ocean.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)

# %%
# You can easily add custom features, e.g. higher-resolution Natural Earth layers

fig = plt.figure(figsize=(20, 20))
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=0.0, globe=None))

ocean_50m = cartopy.feature.NaturalEarthFeature(
    'physical', 'ocean', '50m',
    facecolor=cartopy.feature.COLORS['water']
)

ax.add_feature(ocean_50m)

# %%
# Or a stock physical map background

fig = plt.figure(figsize=(20, 20))
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=0.0, globe=None))

ax.stock_img()

# %%
import plotly.graph_objs as go
import plotly.offline as pltly
pltly.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df_map = pd.read_csv('./data/conventional_power_plants_EU.csv')
df_map = df_map.dropna(subset=['lat', 'lon'])
data = []
opacity = (df_map.capacity/df_map.capacity.max())/2 + 0.5
text = df_map.energy_source + ' ' + df_map.capacity.astype(str) + 'MW' + ' ' + df_map.country
colors = sns.color_palette('colorblind', 4).as_hex()
energy_sources = set(df_map.energy_source_level_1)
for source in energy_sources:
    color = colors[list(energy_sources).index(source)]
    data.append(dict(type='scattergeo',
                     lon=df_map.loc[df_map.energy_source_level_1==source].lon,
                     lat=df_map.loc[df_map.energy_source_level_1==source].lat,
                     text= text.loc[df_map.energy_source_level_1==source],
                     hoverinfo='text',
                     name=source,
                     marker=dict(opacity=0.5, 
                                 color=color,
                                 size=5, 
                                 line=dict(width=1, color='black'))))
layout=dict(geo=dict(resolution=50,
                     scope='europe',
                     projection=dict(type='mercator'),
                     showocean=True,
                     oceancolor='rgb(151,182,225)',
                     showcoastlines=True,
                     coastlinecolor='red'))
fig = go.Figure(data=data, layout=layout)
pltly.iplot(fig)
# Out:
# <div>
#
#
#             <div id="d146e709-2e1e-4404-ab7c-b0b43bf860f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d146e709-2e1e-4404-ab7c-b0b43bf860f8")) {
#                     Plotly.newPlot(
#                         'd146e709-2e1e-4404-ab7c-b0b43bf860f8',
#                         [{"hoverinfo": "text", "lat": [52.47155, 51.154090000000004, 52.47708000000001, 43.42801, 50.02798, 50.02798, 50.02798, 50.02798, 49.905429999999996, 49.905429999999996, 49.905429999999996, 49.905429999999996, 50.15367, 50.15367, 50.15367, 50.576809999999995, 50.576809999999995, 50.576809999999995, 50.576809999999995, 50.41435, 50.41435, 50.41435, 50.428709999999995, 50.428709999999995, 50.428709999999995, 50.428709999999995, 50.428709999999995, 50.428709999999995, 50.41879, 50.41879, 50.41879, 50.41879, 50.41879, 50.41879, 50.41879, 50.41879, 50.41879, 50.15457, 50.3824, 50.3824, 50.3824, 50.3824, 61.130618000000005, 41.664695, 43.376356, 43.326125, 41.544164, 37.304832, 42.592962, 41.676927, 37.577487, 41.540841, 41.840604, 41.544164, 37.577487, 37.307796, 41.216921, 43.316241999999995, 54.99551999999999, 55.093709999999994], "lon": [4.63473, 5.90803, 4.58981, 4.88652, 15.454089999999999, 15.454089999999999, 15.454089999999999, 15.454089999999999, 18.465999999999998, 18.465999999999998, 18.465999999999998, 18.465999999999998, 14.12875, 14.12875, 14.12875, 13.78232, 13.78232, 13.78232, 13.78232, 14.41523, 14.41523, 14.41523, 13.676029999999999, 13.676029999999999, 13.676029999999999, 13.676029999999999, 13.676029999999999, 13.676029999999999, 13.26039, 13.26039, 13.26039, 13.26039, 13.26039, 13.26039, 13.26039, 13.26039, 13.26039, 12.61445, 13.34085, 13.34085, 13.34085, 13.34085, 28.45412, -3.710235, -4.042517, -3.107429, -0.675767, -6.863907000000001, -1.2787190000000002, -4.70961, -0.9176129999999999, -0.6778569999999999, -4.558087, -0.675767, -0.9176129999999999, -6.861567999999999, -0.294205, -5.876937, 11.88538, 14.69715], "marker": {"color": "#0173b2", "line": {"color": "black", "width": 1}, "opacity": 0.5, "size": 5}, "name": "Other or unspecified energy sources", "text": ["Other or unspecified energy sources 144.0MW NL", "Other or unspecified energy sources 510.0MW NL", "Other or unspecified energy sources 38.0MW NL", "Other or unspecified energy sources 62.0MW FR", "Other or unspecified energy sources 200.0MW CZ", "Other or unspecified energy sources 200.0MW CZ", "Other or unspecified energy sources 200.0MW CZ", "Other or unspecified energy sources 200.0MW CZ", "Other or unspecified energy sources 0.0MW CZ", "Other or unspecified energy sources 200.0MW CZ", "Other or unspecified energy sources 200.0MW CZ", "Other or unspecified energy sources 200.0MW CZ", "Other or unspecified energy sources 135.0MW CZ", "Other or unspecified energy sources 135.0MW CZ", "Other or unspecified energy sources 135.0MW CZ", "Other or unspecified energy sources 0.0MW CZ", "Other or unspecified energy sources 0.0MW CZ", "Other or unspecified energy sources 105.0MW CZ", "Other or unspecified energy sources 660.0MW CZ", "Other or unspecified energy sources 96.0MW CZ", "Other or unspecified energy sources 100.0MW CZ", "Other or unspecified energy sources 450.0MW CZ", "Other or unspecified energy sources 845.0MW CZ", "Other or unspecified energy sources 200.0MW CZ", "Other or unspecified energy sources 200.0MW CZ", "Other or unspecified energy sources 200.0MW CZ", "Other or unspecified energy sources 200.0MW CZ", "Other or unspecified energy sources 200.0MW CZ", "Other or unspecified energy sources 105.0MW CZ", "Other or unspecified energy sources 105.0MW CZ", "Other or unspecified energy sources 105.0MW CZ", "Other or unspecified energy sources 105.0MW CZ", "Other or unspecified energy sources 150.0MW CZ", "Other or unspecified energy sources 185.0MW CZ", "Other or unspecified energy sources 250.0MW CZ", "Other or unspecified energy sources 250.0MW CZ", "Other or unspecified energy sources 250.0MW CZ", "Other or unspecified energy sources 105.0MW CZ", "Other or unspecified energy sources 200.0MW CZ", "Other or unspecified energy sources 200.0MW CZ", "Other or unspecified energy sources 200.0MW CZ", "Other or unspecified energy sources 200.0MW CZ", "Other or unspecified energy sources 3.9MW FI", "Other or unspecified ene ...

# %% [markdown]
# ## Further reading
#
# Other examples:
#
#
# * Using Enipedia data to map the world's nuclear power plants (2014): https://www.pfenninger.org/posts/mapping-the-worlds-nuclear-power-plants
